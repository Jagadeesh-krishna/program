# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagadeesh-krishna/program/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
# series
arr=np.array([10,20,30,40,50])
marks=pd.Series(arr)
print(marks)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
marks=pd.Series(
    [100,100,100],
    index=["maths", "science", "english"]
)
print(marks)
print(marks["maths"])
print(marks.shape)
print(marks.size)
print(marks.dtype)
print(marks.values)
print(marks.index)
# Out:
# maths      100
# science    100
# english    100
# dtype: int64
# 100
# (3,)
# 3
# int64
# [100 100 100]
# Index(['maths', 'science', 'english'], dtype='object')

# %%
numbers=[1,2,34,7]
result=[]
for i in numbers:
  result.append(i*2)
print(result)
# Out:
# [2, 4, 68, 14]

# %%
# vectorized operation means applying one operation to all elements automatically without writing loops
numbers=[1,2,34,7]
arr=np.array(numbers)
print(arr*2)
# Out:
# [ 2  4 68 14]

# %%
data=pd.Series([1,2,3,4,np.nan,5])
print(data.isnull()) #to know the missing value
print(data.fillna(0)) #repleace the null value with any value
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    0.0
# 5    5.0
# dtype: float64

# %%
# dataframe
data={
    "name":["A","B", "C","D" ],
    "marks":[60,70,80,90],
    "grade":["b","b","a", "a"]
}
df=pd.DataFrame(data)
print(df)
print(df.shape)
print(df.size)
print(df.columns)
print(df.index)
print(df.tail)
# Out:
#   name  marks grade
# 0    A     60     b
# 1    B     70     b
# 2    C     80     a
# 3    D     90     a
# (4, 3)
# 12
# Index(['name', 'marks', 'grade'], dtype='object')
# RangeIndex(start=0, stop=4, step=1)
# <bound method NDFrame.tail of   name  marks grade
# 0    A     60     b
# 1    B     70     b
# 2    C     80     a
# 3    D     90     a>

# %%
df["City"]=["tirupati", "renigunta", "Tokyo", "wuhan"]
print(df)
# Out:
#   name  marks grade       City
# 0    A     60     b   tirupati
# 1    B     70     b  renigunta
# 2    C     80     a      Tokyo
# 3    D     90     a      wuhan

# %%
df["marks"]=df["marks"]+20
print(df)
df.drop("City", axis=1)
# Out:
#   name  marks grade       City
# 0    A    100     b   tirupati
# 1    B    110     b  renigunta
# 2    C    120     a      Tokyo
# 3    D    130     a      wuhan
#   name  marks grade
# 0    A    100     b
# 1    B    110     b
# 2    C    120     a
# 3    D    130     a

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/data science/student_dataset_20rows.csv")
print(df)
# Out:
#     Student_ID     Name  Age            Course  Marks         City
# 0          101      Ram   25            Pandas     90   Vijayawada
# 1          102     Ravi   23             NumPy     81    Hyderabad
# 2          103     Sita   21            Python     80      Chennai
# 3          104    Kiran   21      Data Science     98    Bangalore
# 4          105      Anu   20            Pandas     70       Mumbai
# 5          106    Rahul   22               SQL     82        Delhi
# 6          107    Sneha   25     Deep Learning     79         Pune
# 7          108    Arjun   22  Machine Learning     70      Kolkata
# 8          109    Pooja   20            Python     95        Vizag
# 9          110   Vikram   20               SQL     72     Tirupati
# 10         111    Divya   23     Deep Learning     94     Warangal
# 11         112     Ajay   21            Python     84       Guntur
# 12         113  Keerthi   21             NumPy     74      Nellore
# ...

# %%
df=pd.read_json("/content/drive/MyDrive/data science/student_dataset_20rows.json")
print(df)
# Out:
#     Student_ID     Name  Age            Course  Marks         City
# 0          101      Ram   25            Pandas     90   Vijayawada
# 1          102     Ravi   23             NumPy     81    Hyderabad
# 2          103     Sita   21            Python     80      Chennai
# 3          104    Kiran   21      Data Science     98    Bangalore
# 4          105      Anu   20            Pandas     70       Mumbai
# 5          106    Rahul   22               SQL     82        Delhi
# 6          107    Sneha   25     Deep Learning     79         Pune
# 7          108    Arjun   22  Machine Learning     70      Kolkata
# 8          109    Pooja   20            Python     95        Vizag
# 9          110   Vikram   20               SQL     72     Tirupati
# 10         111    Divya   23     Deep Learning     94     Warangal
# 11         112     Ajay   21            Python     84       Guntur
# 12         113  Keerthi   21             NumPy     74      Nellore
# ...

# %%
df=pd.read_excel("/content/drive/MyDrive/data science/student_dataset_20rows.xlsx")
print(df)
# Out:
#     Student_ID     Name  Age            Course  Marks         City
# 0          101      Ram   25            Pandas     90   Vijayawada
# 1          102     Ravi   23             NumPy     81    Hyderabad
# 2          103     Sita   21            Python     80      Chennai
# 3          104    Kiran   21      Data Science     98    Bangalore
# 4          105      Anu   20            Pandas     70       Mumbai
# 5          106    Rahul   22               SQL     82        Delhi
# 6          107    Sneha   25     Deep Learning     79         Pune
# 7          108    Arjun   22  Machine Learning     70      Kolkata
# 8          109    Pooja   20            Python     95        Vizag
# 9          110   Vikram   20               SQL     72     Tirupati
# 10         111    Divya   23     Deep Learning     94     Warangal
# 11         112     Ajay   21            Python     84       Guntur
# 12         113  Keerthi   21             NumPy     74      Nellore
# ...

# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/data science/student_dataset_20rows.xlsx")
print(df)
# Out:
#     Student_ID     Name  Age            Course  Marks         City
# 0          101      Ram   25            Pandas     90   Vijayawada
# 1          102     Ravi   23             NumPy     81    Hyderabad
# 2          103     Sita   21            Python     80      Chennai
# 3          104    Kiran   21      Data Science     98    Bangalore
# 4          105      Anu   20            Pandas     70       Mumbai
# 5          106    Rahul   22               SQL     82        Delhi
# 6          107    Sneha   25     Deep Learning     79         Pune
# 7          108    Arjun   22  Machine Learning     70      Kolkata
# 8          109    Pooja   20            Python     95        Vizag
# 9          110   Vikram   20               SQL     72     Tirupati
# 10         111    Divya   23     Deep Learning     94     Warangal
# 11         112     Ajay   21            Python     84       Guntur
# 12         113  Keerthi   21             NumPy     74      Nellore
# ...

# %%
# axis=0 for removing rows
# axis =1 for removing columns
df.drop("City", axis=1, inplace=True)
print(df)
# Out:
#     Student_ID     Name  Age            Course  Marks
# 0          101      Ram   25            Pandas     90
# 1          102     Ravi   23             NumPy     81
# 2          103     Sita   21            Python     80
# 3          104    Kiran   21      Data Science     98
# 4          105      Anu   20            Pandas     70
# 5          106    Rahul   22               SQL     82
# 6          107    Sneha   25     Deep Learning     79
# 7          108    Arjun   22  Machine Learning     70
# 8          109    Pooja   20            Python     95
# 9          110   Vikram   20               SQL     72
# 10         111    Divya   23     Deep Learning     94
# 11         112     Ajay   21            Python     84
# 12         113  Keerthi   21             NumPy     74
# 13         114   Nikhil   22     Deep Learning     99
# 14         115    Meena   23                AI     81
# 15         116      Sai   25            Pandas     97
# ...

# %%
df.drop(0, axis=0, inplace=True)

# %%
df
# Out:
#     Student_ID     Name  Age            Course  Marks
# 1          102     Ravi   23             NumPy     81
# 2          103     Sita   21            Python     80
# 3          104    Kiran   21      Data Science     98
# 4          105      Anu   20            Pandas     70
# 5          106    Rahul   22               SQL     82
# 6          107    Sneha   25     Deep Learning     79
# 7          108    Arjun   22  Machine Learning     70
# 8          109    Pooja   20            Python     95
# 9          110   Vikram   20               SQL     72
# 10         111    Divya   23     Deep Learning     94
# 11         112     Ajay   21            Python     84
# 12         113  Keerthi   21             NumPy     74
# 13         114   Nikhil   22     Deep Learning     99
# 14         115    Meena   23                AI     81
# 15         116      Sai   25            Pandas     97
# 16         117  Lavanya   20                AI     72
# ...

# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/data science/student_dataset_20rows.xlsx")
print(df)
# Out:
#     Student_ID     Name  Age            Course  Marks         City
# 0          101      Ram   25            Pandas     90   Vijayawada
# 1          102     Ravi   23             NumPy     81    Hyderabad
# 2          103     Sita   21            Python     80      Chennai
# 3          104    Kiran   21      Data Science     98    Bangalore
# 4          105      Anu   20            Pandas     70       Mumbai
# 5          106    Rahul   22               SQL     82        Delhi
# 6          107    Sneha   25     Deep Learning     79         Pune
# 7          108    Arjun   22  Machine Learning     70      Kolkata
# 8          109    Pooja   20            Python     95        Vizag
# 9          110   Vikram   20               SQL     72     Tirupati
# 10         111    Divya   23     Deep Learning     94     Warangal
# 11         112     Ajay   21            Python     84       Guntur
# 12         113  Keerthi   21             NumPy     74      Nellore
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'City'], dtype='object')

# %%
df["Marks"]
# Out:
# 0     90
# 1     81
# 2     80
# 3     98
# 4     70
# 5     82
# 6     79
# 7     70
# 8     95
# 9     72
# 10    94
# 11    84
# 12    74
# 13    99
# 14    81
# 15    97
# 16    72
# 17    70
# 18    90
# 19    78
# Name: Marks, dtype: int64

# %%
df["Name"]
# Out:
# 0         Ram
# 1        Ravi
# 2        Sita
# 3       Kiran
# 4         Anu
# 5       Rahul
# 6       Sneha
# 7       Arjun
# 8       Pooja
# 9      Vikram
# 10      Divya
# 11       Ajay
# 12    Keerthi
# 13     Nikhil
# 14      Meena
# 15        Sai
# 16    Lavanya
# 17      Rohit
# 18       Teja
# 19      Priya
# Name: Name, dtype: object

# %%
df["Age"]
# Out:
# 0     25
# 1     23
# 2     21
# 3     21
# 4     20
# 5     22
# 6     25
# 7     22
# 8     20
# 9     20
# 10    23
# 11    21
# 12    21
# 13    22
# 14    23
# 15    25
# 16    20
# 17    23
# 18    25
# 19    22
# Name: Age, dtype: int64

# %%
df["Course"]
# Out:
# 0               Pandas
# 1                NumPy
# 2               Python
# 3         Data Science
# 4               Pandas
# 5                  SQL
# 6        Deep Learning
# 7     Machine Learning
# 8               Python
# 9                  SQL
# 10       Deep Learning
# 11              Python
# 12               NumPy
# 13       Deep Learning
# 14                  AI
# 15              Pandas
# 16                  AI
# 17              Python
# 18    Machine Learning
# 19                 SQL
# Name: Course, dtype: object

# %%
df[["Name","Age"]]
# Out:
#        Name  Age
# 0       Ram   25
# 1      Ravi   23
# 2      Sita   21
# 3     Kiran   21
# 4       Anu   20
# 5     Rahul   22
# 6     Sneha   25
# 7     Arjun   22
# 8     Pooja   20
# 9    Vikram   20
# 10    Divya   23
# 11     Ajay   21
# 12  Keerthi   21
# 13   Nikhil   22
# 14    Meena   23
# 15      Sai   25
# 16  Lavanya   20
# 17    Rohit   23
# 18     Teja   25
# 19    Priya   22

# %%
df[["Name", "Age","City"]]
# Out:
#        Name  Age         City
# 0       Ram   25   Vijayawada
# 1      Ravi   23    Hyderabad
# 2      Sita   21      Chennai
# 3     Kiran   21    Bangalore
# 4       Anu   20       Mumbai
# 5     Rahul   22        Delhi
# 6     Sneha   25         Pune
# 7     Arjun   22      Kolkata
# 8     Pooja   20        Vizag
# 9    Vikram   20     Tirupati
# 10    Divya   23     Warangal
# 11     Ajay   21       Guntur
# 12  Keerthi   21      Nellore
# 13   Nikhil   22       Kadapa
# 14    Meena   23      Kurnool
# 15      Sai   25       Ongole
# 16  Lavanya   20  Rajahmundry
# 17    Rohit   23        Eluru
# 18     Teja   25      Khammam
# 19    Priya   22    Nizamabad

# %%
#selecting rows using iloc function
#iloc = integer location
df.iloc[0]
# Out:
# Student_ID           101
# Name                 Ram
# Age                   25
# Course            Pandas
# Marks                 90
# City          Vijayawada
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#    Student_ID  Name  Age  Course  Marks        City
# 0         101   Ram   25  Pandas     90  Vijayawada
# 1         102  Ravi   23   NumPy     81   Hyderabad
# 2         103  Sita   21  Python     80     Chennai

# %%
#selecting specific rows and columns
# df.loc[rowselection, columnselection]
df.iloc[0:3,0:2]
# Out:
#    Student_ID  Name
# 0         101   Ram
# 1         102  Ravi
# 2         103  Sita

# %%
df.iloc[[0,1,2,3]]
# Out:
#    Student_ID   Name  Age        Course  Marks        City
# 0         101    Ram   25        Pandas     90  Vijayawada
# 1         102   Ravi   23         NumPy     81   Hyderabad
# 2         103   Sita   21        Python     80     Chennai
# 3         104  Kiran   21  Data Science     98   Bangalore

# %%
df.loc[:, "Name"]
# Out:
# 0         Ram
# 1        Ravi
# 2        Sita
# 3       Kiran
# 4         Anu
# 5       Rahul
# 6       Sneha
# 7       Arjun
# 8       Pooja
# 9      Vikram
# 10      Divya
# 11       Ajay
# 12    Keerthi
# 13     Nikhil
# 14      Meena
# 15        Sai
# 16    Lavanya
# 17      Rohit
# 18       Teja
# 19      Priya
# Name: Name, dtype: object

# %%
df.loc[:,["Name","City"]]
# Out:
#        Name         City
# 0       Ram   Vijayawada
# 1      Ravi    Hyderabad
# 2      Sita      Chennai
# 3     Kiran    Bangalore
# 4       Anu       Mumbai
# 5     Rahul        Delhi
# 6     Sneha         Pune
# 7     Arjun      Kolkata
# 8     Pooja        Vizag
# 9    Vikram     Tirupati
# 10    Divya     Warangal
# 11     Ajay       Guntur
# 12  Keerthi      Nellore
# 13   Nikhil       Kadapa
# 14    Meena      Kurnool
# 15      Sai       Ongole
# 16  Lavanya  Rajahmundry
# 17    Rohit        Eluru
# 18     Teja      Khammam
# 19    Priya    Nizamabad

# %%
df.loc[5:8,["Name","Age"]]
# Out:
#     Name  Age
# 5  Rahul   22
# 6  Sneha   25
# 7  Arjun   22
# 8  Pooja   20

# %%
df
# Out:
#     Student_ID     Name  Age            Course  Marks         City
# 0          101      Ram   25            Pandas     90   Vijayawada
# 1          102     Ravi   23             NumPy     81    Hyderabad
# 2          103     Sita   21            Python     80      Chennai
# 3          104    Kiran   21      Data Science     98    Bangalore
# 4          105      Anu   20            Pandas     70       Mumbai
# 5          106    Rahul   22               SQL     82        Delhi
# 6          107    Sneha   25     Deep Learning     79         Pune
# 7          108    Arjun   22  Machine Learning     70      Kolkata
# 8          109    Pooja   20            Python     95        Vizag
# 9          110   Vikram   20               SQL     72     Tirupati
# 10         111    Divya   23     Deep Learning     94     Warangal
# 11         112     Ajay   21            Python     84       Guntur
# 12         113  Keerthi   21             NumPy     74      Nellore
# ...

# %% [markdown]
# Task 1

# %%
df["Name"]

# %%
df.loc[:,["Name"]]

# %%
df.iloc[:, 1]

# %% [markdown]
# Task 2

# %%
df[["Name","City"]]

# %%
df.loc[:,["Name", "City"]]

# %%
df.iloc[:, [1, 5]]

# %% [markdown]
# Task 3

# %%
df.loc[0:2]

# %%
df.iloc[:3]

# %% [markdown]
# Task 4

# %%
df.loc[:1, ['Student_ID', 'Name']]

# %%
df.iloc[:2, :2]

# %% [markdown]
# Task 5

# %%
df.loc[:,"Marks"]

# %%
df.iloc[:,4]
