# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagadeesh-krishna/program/blob/main/aggregate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/drive/MyDrive/data science/student_dataset_20rows.xlsx")

# %%
df.head()
# Out:
#    Student_ID   Name  Age        Course  Marks        City
# 0         101    Ram   25        Pandas     90  Vijayawada
# 1         102   Ravi   23         NumPy     81   Hyderabad
# 2         103   Sita   21        Python     80     Chennai
# 3         104  Kiran   21  Data Science     98   Bangalore
# 4         105    Anu   20        Pandas     70      Mumbai

# %%
print(df["Marks"].sum()) #sum: it will calculates sum all the data in that column
# Out:
# 1656

# %%
print(df["Marks"].mean()) #calculates the mean
# Out:
# 82.8

# %%
print(df["Marks"].median()) # calculates the median
# Out:
# 81.0

# %%
print(df["Marks"].min()) # show the min value
# Out:
# 70

# %%
df["Marks"].max()
# Out:
# 99

# %%
df["Marks"].count()
# Out:
# np.int64(20)

# %%
df["Marks"].std()
# Out:
# 10.076549116898263

# %%
df["Marks"].var()
# Out:
# 101.53684210526318

# %%
df["Marks"].describe()

# %%
df["Marks"].agg(["sum","mean"])

# %%
import seaborn as sns
import pandas as pd
# Load dataset
df = sns.load_dataset("tips")
# Display first 5 rows
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["total_bill"].sum()
# Out:
# np.float64(4827.77)

# %%
g=df.groupby("city")

# %%
for city, city_df in g:
  print(city)
  print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group("mumbai")

# %%
df.columns
# Out:
# Index(['day', 'city', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.groupby("city")["temperature"].max()
# Out:
# city
# mumbai      92
# new york    36
# paris       54
# Name: temperature, dtype: int64

# %%
# find average wind speed per city
df.groupby("city")["windspeed"].mean()
# Out:
# city
# mumbai       9.25
# new york     8.00
# paris       12.75
# Name: windspeed, dtype: float64

# %%
df.groupby("city")["windspeed"].sum()
# Out:
# city
# mumbai      37
# new york    32
# paris       51
# Name: windspeed, dtype: int64

# %%
df.groupby("city")["windspeed"].max()
# Out:
# city
# mumbai      15
# new york    12
# paris       20
# Name: windspeed, dtype: int64
