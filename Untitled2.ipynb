# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagadeesh-krishna/program/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/data science/string_processing_dataset (1).csv")

# %%
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  Vijayawada         Rs 1000
# 1           RAJU KUMAR      RAJU@YAHOO.COM   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      vizag         Rs 3,500
# 3        SURESH BABU    suresh@outlook.com      Guntur          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["email"]=df["email"].str.lower(
)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  Vijayawada         Rs 1000
# 1           RAJU KUMAR      raju@yahoo.com   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      vizag         Rs 3,500
# 3        SURESH BABU    suresh@outlook.com      Guntur          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["city"]=df["city"].str.upper()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA         Rs 1000
# 1           RAJU KUMAR      raju@yahoo.com   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      VIZAG         Rs 3,500
# 3        SURESH BABU    suresh@outlook.com      GUNTUR          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["customer_name"]=df["customer_name"].str.title()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA         Rs 1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD            $250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG         Rs 3,500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["purchase_amount"]=df["purchase_amount"].str.replace("Rs ","", regex=False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD            $250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG            3,500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["purchase_amount"]=df["purchase_amount"].str.replace("$","", regex=False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG            3,500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR           1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["purchase_amount"]=df["purchase_amount"].str.replace(",","", regex=False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["email_parts"]=df["email"].str.contains("gmail")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  email_parts
# 0  9876543210      PRD-101  12-Jan-2024         True
# 1  9123456789      PRD-202  05-Feb-2024        False
# 2  9988776655      PRD-303  18-Mar-2024         True
# 3  9871234567      PRD-404  22-Apr-2024        False
# 4  9012345678      PRD-505  30-May-2024         True

# %%
df["startswithv"]=df["city"].str.startswith("V")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  email_parts  startswithv
# 0  9876543210      PRD-101  12-Jan-2024         True         True
# 1  9123456789      PRD-202  05-Feb-2024        False        False
# 2  9988776655      PRD-303  18-Mar-2024         True        False
# 3  9871234567      PRD-404  22-Apr-2024        False        False
# 4  9012345678      PRD-505  30-May-2024         True        False

# %%
df["email_parts"]=df["email"].str.split("@").str[0]
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date email_parts  startswithv
# 0  9876543210      PRD-101  12-Jan-2024    santhosh         True
# 1  9123456789      PRD-202  05-Feb-2024        raju        False
# 2  9988776655      PRD-303  18-Mar-2024       kiran        False
# 3  9871234567      PRD-404  22-Apr-2024      suresh        False
# 4  9012345678      PRD-505  30-May-2024     lakshmi        False

# %%
df = pd.read_csv("/content/drive/MyDrive/data science/bank_customer_data (1).csv")
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    SANthosh Chevuri  SANTHOSH@GMAIL.COM     hdfc bank      savings
# 1        RAJU kumar        RAJU@YAHOO.COM    ICICI BANK      CURRENT
# 2        kiran REDDY      KIRAN@GMAIL.COM    axis bank       salary
# 3         SURESH BABU  SURESH@OUTLOOK.COM           SBI      SAVINGS
# 4       Lakshmi devi    LAKSHMI@GMAIL.COM    kotak bank      current
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000      vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
# 1
df['customer_name'] = df['customer_name'].str.title()
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  SANTHOSH@GMAIL.COM     hdfc bank      savings
# 1        Raju Kumar        RAJU@YAHOO.COM    ICICI BANK      CURRENT
# 2        Kiran Reddy      KIRAN@GMAIL.COM    axis bank       salary
# 3         Suresh Babu  SURESH@OUTLOOK.COM           SBI      SAVINGS
# 4       Lakshmi Devi    LAKSHMI@GMAIL.COM    kotak bank      current
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000      vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
df['email'] = df['email'].str.lower()
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  santhosh@gmail.com     hdfc bank      savings
# 1        Raju Kumar        raju@yahoo.com    ICICI BANK      CURRENT
# 2        Kiran Reddy      kiran@gmail.com    axis bank       salary
# 3         Suresh Babu  suresh@outlook.com           SBI      SAVINGS
# 4       Lakshmi Devi    lakshmi@gmail.com    kotak bank      current
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000      vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
df['bank_name'] = df['bank_name'].str.upper()
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  santhosh@gmail.com     HDFC BANK      savings
# 1        Raju Kumar        raju@yahoo.com    ICICI BANK      CURRENT
# 2        Kiran Reddy      kiran@gmail.com    AXIS BANK       salary
# 3         Suresh Babu  suresh@outlook.com           SBI      SAVINGS
# 4       Lakshmi Devi    lakshmi@gmail.com    KOTAK BANK      current
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000      vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
df['balance'] = df['balance'].str.replace('Rs', '', regex=False)
df['balance'] = df['balance'].str.replace('$', '', regex=False)
df['balance'] = df['balance'].str.replace(',', '', regex=False)
df['balance'] = df['balance'].str.strip()
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  santhosh@gmail.com     HDFC BANK      savings
# 1        Raju Kumar        raju@yahoo.com    ICICI BANK      CURRENT
# 2        Kiran Reddy      kiran@gmail.com    AXIS BANK       salary
# 3         Suresh Babu  suresh@outlook.com           SBI      SAVINGS
# 4       Lakshmi Devi    lakshmi@gmail.com    KOTAK BANK      current
#
#   account_number balance branch_city
# 0       ACC-1001  125000   hyderabad
# 1       ACC-1002    2500  VIJAYAWADA
# 2       ACC-1003   75000      vizag
# 3       ACC-1004   10000      GUNTUR
# 4       ACC-1005   50500    tirupati

# %%
df['balance'] = df['balance'].astype(int)
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  santhosh@gmail.com     HDFC BANK      savings
# 1        Raju Kumar        raju@yahoo.com    ICICI BANK      CURRENT
# 2        Kiran Reddy      kiran@gmail.com    AXIS BANK       salary
# 3         Suresh Babu  suresh@outlook.com           SBI      SAVINGS
# 4       Lakshmi Devi    lakshmi@gmail.com    KOTAK BANK      current
#
#   account_number  balance branch_city
# 0       ACC-1001   125000   hyderabad
# 1       ACC-1002     2500  VIJAYAWADA
# 2       ACC-1003    75000      vizag
# 3       ACC-1004    10000      GUNTUR
# 4       ACC-1005    50500    tirupati

# %%
df['username'] = df['email'].str.split('@').str[0]
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  santhosh@gmail.com     HDFC BANK      savings
# 1        Raju Kumar        raju@yahoo.com    ICICI BANK      CURRENT
# 2        Kiran Reddy      kiran@gmail.com    AXIS BANK       salary
# 3         Suresh Babu  suresh@outlook.com           SBI      SAVINGS
# 4       Lakshmi Devi    lakshmi@gmail.com    KOTAK BANK      current
#
#   account_number  balance branch_city  username
# 0       ACC-1001   125000   hyderabad  santhosh
# 1       ACC-1002     2500  VIJAYAWADA      raju
# 2       ACC-1003    75000      vizag      kiran
# 3       ACC-1004    10000      GUNTUR    suresh
# 4       ACC-1005    50500    tirupati   lakshmi

# %%
df['domain'] = df['email'].str.split('@').str[1]
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  santhosh@gmail.com     HDFC BANK      savings
# 1        Raju Kumar        raju@yahoo.com    ICICI BANK      CURRENT
# 2        Kiran Reddy      kiran@gmail.com    AXIS BANK       salary
# 3         Suresh Babu  suresh@outlook.com           SBI      SAVINGS
# 4       Lakshmi Devi    lakshmi@gmail.com    KOTAK BANK      current
#
#   account_number  balance branch_city  username       domain
# 0       ACC-1001   125000   hyderabad  santhosh    gmail.com
# 1       ACC-1002     2500  VIJAYAWADA      raju    yahoo.com
# 2       ACC-1003    75000      vizag      kiran    gmail.com
# 3       ACC-1004    10000      GUNTUR    suresh  outlook.com
# 4       ACC-1005    50500    tirupati   lakshmi    gmail.com

# %%
df['branch_code'] = df['branch_city'].str[:3].str.upper()
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  santhosh@gmail.com     HDFC BANK      savings
# 1        Raju Kumar        raju@yahoo.com    ICICI BANK      CURRENT
# 2        Kiran Reddy      kiran@gmail.com    AXIS BANK       salary
# 3         Suresh Babu  suresh@outlook.com           SBI      SAVINGS
# 4       Lakshmi Devi    lakshmi@gmail.com    KOTAK BANK      current
#
#   account_number  balance branch_city  username       domain branch_code
# 0       ACC-1001   125000   hyderabad  santhosh    gmail.com         HYD
# 1       ACC-1002     2500  VIJAYAWADA      raju    yahoo.com         VIJ
# 2       ACC-1003    75000      vizag      kiran    gmail.com          VI
# 3       ACC-1004    10000      GUNTUR    suresh  outlook.com         GUN
# 4       ACC-1005    50500    tirupati   lakshmi    gmail.com         TIR

# %%
df['account_number'] = df['account_number'].str.replace('ACC-', '', regex=False)
df
# Out:
#         customer_name               email     bank_name account_type  \
# 0    Santhosh Chevuri  santhosh@gmail.com     HDFC BANK      savings
# 1        Raju Kumar        raju@yahoo.com    ICICI BANK      CURRENT
# 2        Kiran Reddy      kiran@gmail.com    AXIS BANK       salary
# 3         Suresh Babu  suresh@outlook.com           SBI      SAVINGS
# 4       Lakshmi Devi    lakshmi@gmail.com    KOTAK BANK      current
#
#   account_number  balance branch_city  username       domain branch_code
# 0           1001   125000   hyderabad  santhosh    gmail.com         HYD
# 1           1002     2500  VIJAYAWADA      raju    yahoo.com         VIJ
# 2           1003    75000      vizag      kiran    gmail.com          VI
# 3           1004    10000      GUNTUR    suresh  outlook.com         GUN
# 4           1005    50500    tirupati   lakshmi    gmail.com         TIR
